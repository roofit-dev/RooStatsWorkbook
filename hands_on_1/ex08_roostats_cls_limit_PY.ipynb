# %% [markdown]
# # Perform CLs limit calculation

# %%
import ROOT
# %jsroot on
# Out:
# Welcome to JupyROOT 6.12/06

# %% [markdown]
# Open the `ROOT` file

# %%
f = ROOT.TFile.Open("../workspaces/model.root")
# Out:
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

# %% [markdown]
# Retrieve the workspace

# %%
w = f.Get("w")
w.Print()
# Out:
# RooWorkspace(w) w contents
#
# variables
# ---------
# (B_nom,B_systerr,Nobs_SR,S,alphaB_nom,alpha_B,mu)
#
# p.d.f.s
# -------
# RooProdPdf::model[ model_SR * model_alphaB ] = 0.0511153
# RooPoisson::model_SR[ x=Nobs_SR mean=Nexp_SR ] = 0.0511153
# RooGaussian::model_alphaB[ x=alphaB_nom mean=alpha_B sigma=1 ] = 1
#
# functions
# --------
# RooFormulaVar::B[ actualVars=(B_nom,alpha_B,B_systerr) formula="B_nom+alpha_B*B_systerr" ] = 20
# RooFormulaVar::Nexp_SR[ actualVars=(mu,S,B) formula="mu*S+B" ] = 30
#
# datasets
# --------
# RooDataSet::observed_data(Nobs_SR)
#
# parameter snapshots
# -------------------
# ModelConfig__snapshot = (mu=1)
#
# named sets
# ----------
# ModelConfig_GlobalObservables:(alphaB_nom)
# ModelConfig_NuisParams:(alpha_B)
# ModelConfig_Observables:(Nobs_SR)
# ModelConfig_POI:(mu)
# ModelConfig__snapshot:(mu)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig

# %% [markdown]
# ### Retrieve the ModelConfig for the S+B hypothesis
#
# Retrieve the ModelConfig and the observed data. Together these uniquely define the statistical problem

# %%
data = w.data("observed_data")
sbModel = w.obj("ModelConfig")

# %% [markdown]
# ## Construct a ModelConfig for the B-only hypothesis
#
# For a CLS-style limit calculation (hypothesis test inversion) we need an explicit specification of the background-only hypothesis == another RooStats::ModelConfig that describe the B-only scenario

# %%
bModel = sbModel.Clone("BonlyModel")

# %% [markdown]
# Here we take a little shortcut from universality by assuming that the POI=0 scenario corresponds to the background-only scenario
#
# Set value POI parameter to zero

# %%
poi = bModel.GetParametersOfInterest().first()
poi.setVal(0)

# %% [markdown]
# Configure bModel to encode current poi=0 scenario as its hypothesis

# %%
bModel.SetSnapshot( ROOT.RooArgSet(poi)  )

# %% [markdown]
# *NB: To make CLS-style hypothesis calculation macros truly universal workspace files should contain both ModelConfigs upfront*
#
# ### Construct an hypothesis p-value calculator
# i.e the calculation of p(sbModel) and p(bModel) for the observed data
#
# Instantiate hypothesis testing calculator assuming asymptotic distributions of the profile likelihood ratio (`PLR`) test statistic. This calculator is fast because it does not need to generate toy data to obtain the distribution of the `PLR` under either hypothesis. It is however only valid at sufficiently high statistics.

# %%
asympCalc = ROOT.RooStats.AsymptoticCalculator(data, bModel, sbModel)
# Out:
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize....
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize - Find  best unconditional NLL on observed data
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **    1 **SET PRINT           0
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      0.00000e+00  1.00000e+00   -5.00000e+00  5.00000e+00
#      2 mu           0.00000e+00  5.00000e-01   -1.00000e+00  1.00000e+01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           0
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  **********
#  **    6 **MIGRAD        1000           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.45065 FROM MIGRAD    STATUS=CONVERGED      35 CALLS          36 TOTAL
#                      EDM=2.3272e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      1.49151e-03   9.93113e-01   2.14908e-04   8.74351e-03
#    2  mu           4.99564e-01   6.37106e-01   1.81833e-04   2.42696e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.45065	fit time : Real time 0:00:00, CP time 0.050
# [#0] PROGRESS:Eval -- Best fitted POI value = 0.499564 +/- 0.637106
# [#0] PROGRESS:Eval -- AsymptoticCalculator: Building Asimov data Set
# [#1] INFO:InputArguments -- AsymptoticCalculator: Asimov data will be generated using fitted nuisance parameter values
# MakeAsimov: Setting poi mu to a constant value = 0
# MakeAsimov: doing a conditional fit for finding best nuisance values
#  **********
#  **    1 **SET PRINT           0
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           0
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  **********
#  **    6 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.77092 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.3588e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      5.24910e-01   7.38706e-01   2.12183e-04  -2.47206e-04
#                                ERR DEF= 0.5
# fit time Real time 0:00:00, CP time 0.000
# Generated Asimov data for observables RooArgSet:: = (Nobs_SR)
# Generated Asimov data for global observables RooArgSet:: = (alphaB_nom)
# [#0] PROGRESS:Eval -- AsymptoticCalculator::Initialize Find  best conditional NLL on ASIMOV data set for given alt POI ( mu ) = 0
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **    7 **SET PRINT           0
#  **********
#  **********
#  **    8 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      5.24910e-01  7.38706e-01   -5.00000e+00  5.00000e+00
#  **********
#  **    9 **SET ERR         0.5
#  **********
#  **********
#  **   10 **SET PRINT           0
#  **********
#  **********
#  **   11 **SET STR           1
#  **********
#  **********
#  **   12 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=3.38943 FROM MIGRAD    STATUS=CONVERGED      13 CALLS          14 TOTAL
#                      EDM=1.07666e-20    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      5.24910e-01   7.58635e-01   0.00000e+00  -9.58045e-10
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.38943 for poi fixed at = 0	fit time : Real time 0:00:00, CP time 0.000

# %% [markdown]
# Configure calculator for a limit (=one-sided interval)

# %%
asympCalc.SetOneSided(True)

# %% [markdown]
# ### Construct an hypothesis test inverter
#
# i.e. a tool that can calculate the POI value for which (in this case) CLS==$p(\mathrm{sbModel})/(1-p(\mathrm{Model}))$ takes a certain value. This inversion requires a scan over possible values of $\mu$.

# %%
inverter = ROOT.RooStats.HypoTestInverter(asympCalc)
# Out:
# [#1] INFO:InputArguments -- HypoTestInverter ---- Input models:
# 		 using as S+B (null) model     : ModelConfig
# 		 using as B (alternate) model  : BonlyModel

# %% [markdown]
# Statistical configuration of hypothesis test inverter

# %%
inverter.SetConfidenceLevel(0.90)
inverter.UseCLs(True)

# %% [markdown]
# Technical configuration of hypothesis test inverter

# %%
inverter.SetVerbose(False)
inverter.SetFixedScan(50,0.0,6.0) # set number of points , xmin and xmax

# %% [markdown]
# Perform calculation of limit

# %%
result = inverter.GetInterval()
# Out:
# [#1] INFO:Eval -- HypoTestInverter::GetInterval - run a fixed scan
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   13 **SET PRINT           0
#  **********
#  **********
#  **   14 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   15 **SET ERR         0.5
#  **********
#  **********
#  **   16 **SET PRINT           0
#  **********
#  **********
#  **   17 **SET STR           1
#  **********
#  **********
#  **   18 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.77092 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.3588e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      5.24910e-01   7.38706e-01   2.12183e-04  -2.47206e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.77092 for poi fixed at = 0	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.640533 condNLL = 3.77092 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   19 **SET PRINT           0
#  **********
#  **********
#  **   20 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      5.24910e-01  7.38706e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   21 **SET ERR         0.5
#  **********
#  **********
#  **   22 **SET PRINT           0
#  **********
#  **********
#  **   23 **SET STR           1
#  **********
#  **********
#  **   24 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=3.38943 FROM MIGRAD    STATUS=CONVERGED      13 CALLS          14 TOTAL
#                      EDM=1.07666e-20    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      5.24910e-01   7.58635e-01   0.00000e+00  -9.58045e-10
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.38943 for poi fixed at = 0	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = -1.42109e-14 condNLL = 3.38943 uncond 3.38943
# [#1] INFO:InputArguments -- Minimum of POI is -1 is different to alt snapshot 0 - using standard q asymptotic formulae
# [#1] INFO:Eval -- Using one-sided qmu - setting qmu to zero  muHat = 0.499564 muTest = 0
# [#0] PROGRESS:Eval -- poi = 0 qmu = 0 qmu_A = 0 sigma = -nan  CLsplusb = 0.5 CLb = 0.5 CLs = 1
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.122449
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   25 **SET PRINT           0
#  **********
#  **********
#  **   26 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   27 **SET ERR         0.5
#  **********
#  **********
#  **   28 **SET PRINT           0
#  **********
#  **********
#  **   29 **SET STR           1
#  **********
#  **********
#  **   30 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.63108 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=3.67554e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      3.88952e-01   7.48631e-01   2.11322e-04  -4.02160e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.63108 for poi fixed at = 0.122449	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.360867 condNLL = 3.63108 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   31 **SET PRINT           0
#  **********
#  **********
#  **   32 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      3.88952e-01  7.48631e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   33 **SET ERR         0.5
#  **********
#  **********
#  **   34 **SET PRINT           0
#  **********
#  **********
#  **   35 **SET STR           1
#  **********
#  **********
#  **   36 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.40886 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.36615e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      3.98729e-01   7.68657e-01   2.11199e-04  -7.54858e-05
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.40886 for poi fixed at = 0.122449	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 0.0388669 condNLL = 3.40886 uncond 3.38943
# [#1] INFO:Eval -- Using one-sided qmu - setting qmu to zero  muHat = 0.499564 muTest = 0.122449
# [#0] PROGRESS:Eval -- poi = 0.122449 qmu = 0 qmu_A = 0.0388669 sigma = 0.621105  CLsplusb = 0.5 CLb = 0.578144 CLs = 1.15629
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.244898
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   37 **SET PRINT           0
#  **********
#  **********
#  **   38 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   39 **SET ERR         0.5
#  **********
#  **********
#  **   40 **SET PRINT           0
#  **********
#  **********
#  **   41 **SET STR           1
#  **********
#  **********
#  **   42 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.53206 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=4.46528e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      2.53357e-01   7.58065e-01   2.07085e-04  -4.38477e-02
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.53206 for poi fixed at = 0.244898	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.162821 condNLL = 3.53206 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   43 **SET PRINT           0
#  **********
#  **********
#  **   44 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      2.53357e-01  7.58065e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   45 **SET ERR         0.5
#  **********
#  **********
#  **   46 **SET PRINT           0
#  **********
#  **********
#  **   47 **SET STR           1
#  **********
#  **********
#  **   48 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.4662 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=3.57757e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      2.77230e-01   7.78363e-01   2.14871e-04  -3.82066e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.4662 for poi fixed at = 0.244898	fit time : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 0.153536 condNLL = 3.4662 uncond 3.38943
# [#1] INFO:Eval -- Using one-sided qmu - setting qmu to zero  muHat = 0.499564 muTest = 0.244898
# [#0] PROGRESS:Eval -- poi = 0.244898 qmu = 0 qmu_A = 0.153536 sigma = 0.625001  CLsplusb = 0.5 CLb = 0.65241 CLs = 1.30482
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.367347
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   49 **SET PRINT           0
#  **********
#  **********
#  **   50 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   51 **SET ERR         0.5
#  **********
#  **********
#  **   52 **SET PRINT           0
#  **********
#  **********
#  **   53 **SET STR           1
#  **********
#  **********
#  **   54 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.47239 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=2.37428e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      1.30801e-01   7.67729e-01   2.10287e-04  -9.99211e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.47239 for poi fixed at = 0.367347	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.0434866 condNLL = 3.47239 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   55 **SET PRINT           0
#  **********
#  **********
#  **   56 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.30801e-01  7.67729e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   57 **SET ERR         0.5
#  **********
#  **********
#  **   58 **SET PRINT           0
#  **********
#  **********
#  **   59 **SET STR           1
#  **********
#  **********
#  **   60 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.56 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=6.02784e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      1.60374e-01   7.87745e-01   2.19786e-04  -4.90486e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.56 for poi fixed at = 0.367347	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 0.341149 condNLL = 3.56 uncond 3.38943
# [#1] INFO:Eval -- Using one-sided qmu - setting qmu to zero  muHat = 0.499564 muTest = 0.367347
# [#0] PROGRESS:Eval -- poi = 0.367347 qmu = 0 qmu_A = 0.341149 sigma = 0.628933  CLsplusb = 0.5 CLb = 0.720417 CLs = 1.44083
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.489796
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   61 **SET PRINT           0
#  **********
#  **********
#  **   62 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   63 **SET ERR         0.5
#  **********
#  **********
#  **   64 **SET PRINT           0
#  **********
#  **********
#  **   65 **SET STR           1
#  **********
#  **********
#  **   66 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.45078 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=3.33998e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      9.96581e-03   7.76948e-01   2.14033e-04  -3.70413e-05
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.45078 for poi fixed at = 0.489796	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.000251888 condNLL = 3.45078 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   67 **SET PRINT           0
#  **********
#  **********
#  **   68 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      9.96581e-03  7.76948e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   69 **SET ERR         0.5
#  **********
#  **********
#  **   70 **SET PRINT           0
#  **********
#  **********
#  **   71 **SET STR           1
#  **********
#  **********
#  **   72 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.68888 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.13628e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B      4.80269e-02   7.96794e-01   2.25688e-04  -6.66026e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.68888 for poi fixed at = 0.489796	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 0.598909 condNLL = 3.68888 uncond 3.38943
# [#1] INFO:Eval -- Using one-sided qmu - setting qmu to zero  muHat = 0.499564 muTest = 0.489796
# [#0] PROGRESS:Eval -- poi = 0.489796 qmu = 0 qmu_A = 0.598909 sigma = 0.632899  CLsplusb = 0.5 CLb = 0.780503 CLs = 1.56101
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.612245
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   73 **SET PRINT           0
#  **********
#  **********
#  **   74 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   75 **SET ERR         0.5
#  **********
#  **********
#  **   76 **SET PRINT           0
#  **********
#  **********
#  **   77 **SET STR           1
#  **********
#  **********
#  **   78 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.46584 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=7.38036e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -1.08368e-01   7.85788e-01   2.18396e-04  -5.44248e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.46584 for poi fixed at = 0.612245	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.0303871 condNLL = 3.46584 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   79 **SET PRINT           0
#  **********
#  **********
#  **   80 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -1.08368e-01  7.85788e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   81 **SET ERR         0.5
#  **********
#  **********
#  **   82 **SET PRINT           0
#  **********
#  **********
#  **   83 **SET STR           1
#  **********
#  **********
#  **   84 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.85147 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.93788e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -5.99182e-02   8.05503e-01   2.32548e-04  -8.60277e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.85147 for poi fixed at = 0.612245	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 0.924085 condNLL = 3.85147 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 0.612245 qmu = 0.0303871 qmu_A = 0.924085 sigma = 0.636897  CLsplusb = 0.430807 CLb = 0.784352 CLs = 1.82065
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.734694
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   85 **SET PRINT           0
#  **********
#  **********
#  **   86 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   87 **SET ERR         0.5
#  **********
#  **********
#  **   88 **SET PRINT           0
#  **********
#  **********
#  **   89 **SET STR           1
#  **********
#  **********
#  **   90 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.51628 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.0114e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.23620e-01   7.94292e-01   2.23423e-04  -1.99145e-02
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.51628 for poi fixed at = 0.734694	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.131257 condNLL = 3.51628 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   91 **SET PRINT           0
#  **********
#  **********
#  **   92 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -2.23620e-01  7.94292e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   93 **SET ERR         0.5
#  **********
#  **********
#  **   94 **SET PRINT           0
#  **********
#  **********
#  **   95 **SET STR           1
#  **********
#  **********
#  **   96 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.04644 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=2.7347e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -1.63572e-01   8.13871e-01   2.40318e-04  -1.01088e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.04644 for poi fixed at = 0.734694	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 1.31401 condNLL = 4.04644 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 0.734694 qmu = 0.131257 qmu_A = 1.31401 sigma = 0.640924  CLsplusb = 0.358566 CLb = 0.783483 CLs = 2.18504
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.857143
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **   97 **SET PRINT           0
#  **********
#  **********
#  **   98 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **   99 **SET ERR         0.5
#  **********
#  **********
#  **  100 **SET PRINT           0
#  **********
#  **********
#  **  101 **SET STR           1
#  **********
#  **********
#  **  102 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.60079 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=3.95156e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -3.35371e-01   8.02488e-01   2.29134e-04  -3.89086e-02
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.60079 for poi fixed at = 0.857143	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.300288 condNLL = 3.60079 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  103 **SET PRINT           0
#  **********
#  **********
#  **  104 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -3.35371e-01  8.02488e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  105 **SET ERR         0.5
#  **********
#  **********
#  **  106 **SET PRINT           0
#  **********
#  **********
#  **  107 **SET STR           1
#  **********
#  **********
#  **  108 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.27248 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=3.01665e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.63052e-01   8.21897e-01   2.48946e-04  -1.05034e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.27248 for poi fixed at = 0.857143	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 1.76611 condNLL = 4.27248 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 0.857143 qmu = 0.300288 qmu_A = 1.76611 sigma = 0.644977  CLsplusb = 0.291851 CLb = 0.782588 CLs = 2.68147
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 0.979592
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  109 **SET PRINT           0
#  **********
#  **********
#  **  110 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  111 **SET ERR         0.5
#  **********
#  **********
#  **  112 **SET PRINT           0
#  **********
#  **********
#  **  113 **SET STR           1
#  **********
#  **********
#  **  114 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.71808 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=1.74013e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -4.35350e-01   8.10645e-01   2.31802e-04   8.06941e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.71808 for poi fixed at = 0.979592	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.53487 condNLL = 3.71808 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  115 **SET PRINT           0
#  **********
#  **********
#  **  116 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -4.35350e-01  8.10645e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  117 **SET ERR         0.5
#  **********
#  **********
#  **  118 **SET PRINT           0
#  **********
#  **********
#  **  119 **SET STR           1
#  **********
#  **********
#  **  120 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.52836 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.64697e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -3.58457e-01   8.29584e-01   2.58404e-04  -7.67910e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.52836 for poi fixed at = 0.979592	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 2.27787 condNLL = 4.52836 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 0.979592 qmu = 0.53487 qmu_A = 2.27787 sigma = 0.649054  CLsplusb = 0.232283 CLb = 0.78169 CLs = 3.36524
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 1.10204
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  121 **SET PRINT           0
#  **********
#  **********
#  **  122 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  123 **SET ERR         0.5
#  **********
#  **********
#  **  124 **SET PRINT           0
#  **********
#  **********
#  **  125 **SET STR           1
#  **********
#  **********
#  **  126 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=3.86698 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=2.88006e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -5.36513e-01   8.18315e-01   2.38597e-04   1.02625e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 3.86698 for poi fixed at = 1.10204	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 0.832654 condNLL = 3.86698 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  127 **SET PRINT           0
#  **********
#  **********
#  **  128 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -5.36513e-01  8.18315e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  129 **SET ERR         0.5
#  **********
#  **********
#  **  130 **SET PRINT           0
#  **********
#  **********
#  **  131 **SET STR           1
#  **********
#  **********
#  **  132 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.81286 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=6.3471e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -4.49965e-01   8.36933e-01   2.68552e-04  -4.71775e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.81286 for poi fixed at = 1.10204	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 2.84686 condNLL = 4.81286 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 1.10204 qmu = 0.832654 qmu_A = 2.84686 sigma = 0.653153  CLsplusb = 0.180753 CLb = 0.780761 CLs = 4.31949
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 1.22449
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  133 **SET PRINT           0
#  **********
#  **********
#  **  134 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  135 **SET ERR         0.5
#  **********
#  **********
#  **  136 **SET PRINT           0
#  **********
#  **********
#  **  137 **SET STR           1
#  **********
#  **********
#  **  138 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.04625 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=3.24853e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -6.33854e-01   8.25682e-01   2.46254e-04   1.07760e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.04625 for poi fixed at = 1.22449	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 1.19121 condNLL = 4.04625 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  139 **SET PRINT           0
#  **********
#  **********
#  **  140 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -6.33854e-01  8.25682e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  141 **SET ERR         0.5
#  **********
#  **********
#  **  142 **SET PRINT           0
#  **********
#  **********
#  **  143 **SET STR           1
#  **********
#  **********
#  **  144 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=5.1248 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=3.41562e-12    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -5.37690e-01   8.43951e-01   2.79361e-04  -1.08331e-05
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 5.1248 for poi fixed at = 1.22449	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 3.47074 condNLL = 5.1248 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 1.22449 qmu = 1.19121 qmu_A = 3.47074 sigma = 0.65727  CLsplusb = 0.137543 CLb = 0.779815 CLs = 5.66962
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 1.34694
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  145 **SET PRINT           0
#  **********
#  **********
#  **  146 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  147 **SET ERR         0.5
#  **********
#  **********
#  **  148 **SET PRINT           0
#  **********
#  **********
#  **  149 **SET STR           1
#  **********
#  **********
#  **  150 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.25476 FROM MIGRAD    STATUS=CONVERGED      13 CALLS          14 TOTAL
#                      EDM=2.43751e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -7.27498e-01   8.32747e-01   2.54714e-04   9.23020e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.25476 for poi fixed at = 1.34694	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 1.60822 condNLL = 4.25476 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  151 **SET PRINT           0
#  **********
#  **********
#  **  152 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -7.27498e-01  8.32747e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  153 **SET ERR         0.5
#  **********
#  **********
#  **  154 **SET PRINT           0
#  **********
#  **********
#  **  155 **SET STR           1
#  **********
#  **********
#  **  156 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=5.46306 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.16492e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -6.21769e-01   8.50643e-01   2.90772e-04   6.26376e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 5.46306 for poi fixed at = 1.34694	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 4.14726 condNLL = 5.46306 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 1.34694 qmu = 1.60822 qmu_A = 4.14726 sigma = 0.661404  CLsplusb = 0.102371 CLb = 0.778853 CLs = 7.60816
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 1.46939
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  157 **SET PRINT           0
#  **********
#  **********
#  **  158 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  159 **SET ERR         0.5
#  **********
#  **********
#  **  160 **SET PRINT           0
#  **********
#  **********
#  **  161 **SET STR           1
#  **********
#  **********
#  **  162 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.49137 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=9.22303e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -8.17566e-01   8.39515e-01   2.63917e-04   5.61531e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.49137 for poi fixed at = 1.46939	fit time : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 2.08145 condNLL = 4.49137 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  163 **SET PRINT           0
#  **********
#  **********
#  **  164 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -8.17566e-01  8.39515e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  165 **SET ERR         0.5
#  **********
#  **********
#  **  166 **SET PRINT           0
#  **********
#  **********
#  **  167 **SET STR           1
#  **********
#  **********
#  **  168 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=5.82655 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=6.34906e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -7.02337e-01   8.57019e-01   3.02731e-04   1.44815e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 5.82655 for poi fixed at = 1.46939	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 4.87424 condNLL = 5.82655 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 1.46939 qmu = 2.08145 qmu_A = 4.87424 sigma = 0.665553  CLsplusb = 0.0745493 CLb = 0.777878 CLs = 10.4344
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 1.59184
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  169 **SET PRINT           0
#  **********
#  **********
#  **  170 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  171 **SET ERR         0.5
#  **********
#  **********
#  **  172 **SET PRINT           0
#  **********
#  **********
#  **  173 **SET STR           1
#  **********
#  **********
#  **  174 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=4.75501 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=1.59954e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -9.04179e-01   8.45992e-01   2.73802e-04   2.31322e-05
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 4.75501 for poi fixed at = 1.59184	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 2.60871 condNLL = 4.75501 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  175 **SET PRINT           0
#  **********
#  **********
#  **  176 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -9.04179e-01  8.45992e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  177 **SET ERR         0.5
#  **********
#  **********
#  **  178 **SET PRINT           0
#  **********
#  **********
#  **  179 **SET STR           1
#  **********
#  **********
#  **  180 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=6.21423 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=1.86681e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -7.79533e-01   8.63086e-01   3.15187e-04   2.45972e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 6.21423 for poi fixed at = 1.59184	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 5.6496 condNLL = 6.21423 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 1.59184 qmu = 2.60871 qmu_A = 5.6496 sigma = 0.669715  CLsplusb = 0.053139 CLb = 0.776892 CLs = 14.62
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 1.71429
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  181 **SET PRINT           0
#  **********
#  **********
#  **  182 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  183 **SET ERR         0.5
#  **********
#  **********
#  **  184 **SET PRINT           0
#  **********
#  **********
#  **  185 **SET STR           1
#  **********
#  **********
#  **  186 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=5.04461 FROM MIGRAD    STATUS=CONVERGED      15 CALLS          16 TOTAL
#                      EDM=1.26026e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -9.87452e-01   8.52182e-01   2.84310e-04  -6.42416e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 5.04461 for poi fixed at = 1.71429	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 3.18792 condNLL = 5.04461 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  187 **SET PRINT           0
#  **********
#  **********
#  **  188 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -9.87452e-01  8.52182e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  189 **SET ERR         0.5
#  **********
#  **********
#  **  190 **SET PRINT           0
#  **********
#  **********
#  **  191 **SET STR           1
#  **********
#  **********
#  **  192 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=6.62509 FROM MIGRAD    STATUS=CONVERGED      12 CALLS          13 TOTAL
#                      EDM=4.2182e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
# ...
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 5.5102
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  553 **SET PRINT           0
#  **********
#  **********
#  **  554 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  555 **SET ERR         0.5
#  **********
#  **********
#  **  556 **SET PRINT           0
#  **********
#  **********
#  **  557 **SET STR           1
#  **********
#  **********
#  **  558 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=22.7501 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.61983e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.46659e+00   9.48448e-01   7.22984e-04   1.83076e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 22.7501 for poi fixed at = 5.5102	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 38.5988 condNLL = 22.7501 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  559 **SET PRINT           0
#  **********
#  **********
#  **  560 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -2.46659e+00  9.48448e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  561 **SET ERR         0.5
#  **********
#  **********
#  **  562 **SET PRINT           0
#  **********
#  **********
#  **  563 **SET STR           1
#  **********
#  **********
#  **  564 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=27.0228 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=4.0162e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.14597e+00   9.55162e-01   7.69660e-04   9.40369e-05
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 27.0228 for poi fixed at = 5.5102	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 47.2667 condNLL = 27.0228 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 5.5102 qmu = 38.5988 qmu_A = 47.2667 sigma = 0.801475  CLsplusb = 2.60253e-10 CLb = 0.746105 CLs = 2.86684e+09
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 5.63265
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  565 **SET PRINT           0
#  **********
#  **********
#  **  566 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  567 **SET ERR         0.5
#  **********
#  **********
#  **  568 **SET PRINT           0
#  **********
#  **********
#  **  569 **SET STR           1
#  **********
#  **********
#  **  570 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=23.5092 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.74618e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.49241e+00   9.49792e-01   7.38058e-04   1.89155e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 23.5092 for poi fixed at = 5.63265	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 40.1172 condNLL = 23.5092 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  571 **SET PRINT           0
#  **********
#  **********
#  **  572 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -2.49241e+00  9.49792e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  573 **SET ERR         0.5
#  **********
#  **********
#  **  574 **SET PRINT           0
#  **********
#  **********
#  **  575 **SET STR           1
#  **********
#  **********
#  **  576 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=27.8438 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=4.84294e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.16816e+00   9.56377e-01   7.83791e-04   1.02884e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 27.8438 for poi fixed at = 5.63265	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 48.9088 condNLL = 27.8438 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 5.63265 qmu = 40.1172 qmu_A = 48.9088 sigma = 0.805415  CLsplusb = 1.1959e-10 CLb = 0.745267 CLs = 6.23187e+09
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 5.7551
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  577 **SET PRINT           0
#  **********
#  **********
#  **  578 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  579 **SET ERR         0.5
#  **********
#  **********
#  **  580 **SET PRINT           0
#  **********
#  **********
#  **  581 **SET STR           1
#  **********
#  **********
#  **  582 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=24.2762 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.80398e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.51741e+00   9.51108e-01   7.53225e-04   1.91337e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 24.2762 for poi fixed at = 5.7551	fit time : Real time 0:00:00, CP time 0.010
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 41.6511 condNLL = 24.2762 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  583 **SET PRINT           0
#  **********
#  **********
#  **  584 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -2.51741e+00  9.51108e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  585 **SET ERR         0.5
#  **********
#  **********
#  **  586 **SET PRINT           0
#  **********
#  **********
#  **  587 **SET STR           1
#  **********
#  **********
#  **  588 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=28.6715 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=5.79321e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.18959e+00   9.57588e-01   7.97894e-04   1.12118e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 28.6715 for poi fixed at = 5.7551	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 50.5642 condNLL = 28.6715 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 5.7551 qmu = 41.6511 qmu_A = 50.5642 sigma = 0.809341  CLsplusb = 5.45531e-11 CLb = 0.744438 CLs = 1.36461e+10
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 5.87755
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  589 **SET PRINT           0
#  **********
#  **********
#  **  590 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  591 **SET ERR         0.5
#  **********
#  **********
#  **  592 **SET PRINT           0
#  **********
#  **********
#  **  593 **SET STR           1
#  **********
#  **********
#  **  594 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=25.0507 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.78877e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.54159e+00   9.52413e-01   7.68496e-04   1.89628e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 25.0507 for poi fixed at = 5.87755	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 43.2 condNLL = 25.0507 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  595 **SET PRINT           0
#  **********
#  **********
#  **  596 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -2.54159e+00  9.52413e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  597 **SET ERR         0.5
#  **********
#  **********
#  **  598 **SET PRINT           0
#  **********
#  **********
#  **  599 **SET STR           1
#  **********
#  **********
#  **  600 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=29.5057 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=6.87534e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.21027e+00   9.58815e-01   8.11983e-04   1.21704e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 29.5057 for poi fixed at = 5.87755	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 52.2325 condNLL = 29.5057 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 5.87755 qmu = 43.2 qmu_A = 52.2325 sigma = 0.813253  CLsplusb = 2.471e-11 CLb = 0.743616 CLs = 3.00937e+10
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(w) replacing previous snapshot with name ModelConfig__snapshot
#
# [#1] INFO:Eval -- AsymptoticCalculator::GetHypoTest: - perform  an hypothesis test for  POI ( mu ) = 6
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -  Find  best conditional NLL on OBSERVED data set .....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  601 **SET PRINT           0
#  **********
#  **********
#  **  602 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B      1.49151e-03  9.93113e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  603 **SET ERR         0.5
#  **********
#  **********
#  **  604 **SET PRINT           0
#  **********
#  **********
#  **  605 **SET STR           1
#  **********
#  **********
#  **  606 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=25.8324 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=1.70866e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.56497e+00   9.53725e-01   7.83880e-04   1.84467e-03
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 25.8324 for poi fixed at = 6	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 OBSERVED DATA :  qmu   = 44.7635 condNLL = 25.8324 uncond 3.45065
# [#0] PROGRESS:Eval -- AsymptoticCalculator::GetHypoTest -- Find  best conditional NLL on ASIMOV data set ....
# AsymptoticCalculator::EvaluateNLL  ........ using Minuit / Migrad with strategy  1 and tolerance 1
#  **********
#  **  607 **SET PRINT           0
#  **********
#  **********
#  **  608 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha_B     -2.56497e+00  9.53725e-01   -5.00000e+00  5.00000e+00
#  **********
#  **  609 **SET ERR         0.5
#  **********
#  **********
#  **  610 **SET PRINT           0
#  **********
#  **********
#  **  611 **SET STR           1
#  **********
#  **********
#  **  612 **MIGRAD         500           1
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  FCN=30.3461 FROM MIGRAD    STATUS=CONVERGED      16 CALLS          17 TOTAL
#                      EDM=8.09603e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha_B     -2.23018e+00   9.60085e-01   8.26075e-04   1.31594e-04
#                                ERR DEF= 0.5
# AsymptoticCalculator::EvaluateNLL -  value = 30.3461 for poi fixed at = 6	fit time : Real time 0:00:00, CP time 0.000
# [#0] PROGRESS:Eval -- 	 ASIMOV data qmu_A = 53.9133 condNLL = 30.3461 uncond 3.38943
# [#0] PROGRESS:Eval -- poi = 6 qmu = 44.7635 qmu_A = 53.9133 sigma = 0.817153  CLsplusb = 1.11162e-11 CLb = 0.742802 CLs = 6.68218e+10

# %% [markdown]
# Print observed limit

# %%
print "{}%upper limit: {}".format(100*inverter.ConfidenceLevel(), result.UpperLimit())
# Out:
# 90.0%upper limit: 1.45506912678

# %% [markdown]
# compute expected limit

# %%
print "Expected upper limits, using the B (alternate) model : "
print " expected limit (median) ", result.GetExpectedUpperLimit(0)
print " expected limit (-1 sig) ", result.GetExpectedUpperLimit(-1)
print " expected limit (+1 sig) ", result.GetExpectedUpperLimit(1) 
print " expected limit (-2 sig) ", result.GetExpectedUpperLimit(-2)
print " expected limit (+2 sig) ", result.GetExpectedUpperLimit(2)
# Out:
# Expected upper limits, using the B (alternate) model :
#  expected limit (median)  1.07597252885
#  expected limit (-1 sig)  0.735895516429
#  expected limit (+1 sig)  1.59257661765
#  expected limit (-2 sig)  0.538715078253
#  expected limit (+2 sig)  2.28737709685

# %% [markdown]
# Use the visualization tool of the PLC to show how the interval was calculated

# %%
c1 = ROOT.TCanvas()
plot = ROOT.RooStats.HypoTestInverterPlot("HTI_Result_Plot","HypoTest Scan Result",result)
plot.Draw("CLb 2CL") # plot also CLb and CLs+b 
c1.Draw()
# Out:
# <div id="root_plot_1"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.825000061467294,"fY1":-0.13750001022921,"fX2":7.42500006146729,"fY2":1.23750001024118,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":84.3636351065202,"fYtoAbsPixelk":424.800047191284,"fYtoPixelk":424.800047191284,"fYtoPixel":-343.272722162235,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.825000061467294,"fPixeltoXk":-0.825000061467294,"fPixeltoX":0.0118534484524922,"fAbsPixeltoYk":1.23750001024118,"fPixeltoYk":-0.13750001022921,"fPixeltoY":-0.00291313563658981,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":1.34686524963228e-11,"fUxmax":6.6,"fUymax":1.0999999999985,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":1.34686524963228e-11,"fX2":6.6,"fY2":1.0999999999985,"fBorderSize":1,"fBorderMode":0},{"_typename":"TGraphErrors","fUniqueID":0,"fBits":50332680,"fName":"CLs_observed","fTitle":"Observed CLs","fLineColor":1,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1000,"fMarkerColor":632,"fMarkerStyle":20,"fMarkerSize":1,"fNpoints":50,"fX":[0,0.122448979591837,0.244897959183673,0.36734693877551,0.489795918367347,0.612244897959184,0.73469387755102,0.857142857142857,0.979591836734694,1.10204081632653,1.22448979591837,1.3469387755102,1.46938775510204,1.59183673469388,1.71428571428571,1.83673469387755,1.95918367346939,2.08163265306122,2.20408163265306,2.3265306122449,2.44897959183673,2.57142857142857,2.69387755102041,2.81632653061224,2.93877551020408,3.06122448979592,3.18367346938776,3.30612244897959,3.42857142857143,3.55102040816327,3.6734693877551,3.79591836734694,3.91836734693878,4.04081632653061,4.16326530612245,4.28571428571429,4.40816326530612,4.53061224489796,4.6530612244898,4.77551020408163,4.89795918367347,5.02040816326531,5.14285714285714,5.26530612244898,5.38775510204082,5.51020408163265,5.63265306122449,5.75510204081633,5.87755102040816,6],"fY":[1,0.86483687089358,0.766388756908467,0.694042830570976,0.640612722573697,0.549252999922596,0.457656736653946,0.372930212309462,0.297155337559122,0.231508978896502,0.176378736383348,0.131437909196446,0.0958367710582082,0.068399469309477,0.0478055097394796,0.032735667511553,0.0219739721565864,0.0144668755712225,0.00934672811276082,0.00592932786607277,0.00369534343822126,0.00226385511543408,0.0013640320316223,8.08754055627744e-4,4.72115882497259e-4,2.71492169680308e-4,1.53866985819795e-4,8.59850546724411e-5,4.74042271805744e-5,2.57927884800823e-5,1.38569207653226e-5,7.35370299189841e-6,3.85650025644875e-6,1.99939685028071e-6,1.0251489962865e-6,5.20013995418205e-7,2.61056631138051e-7,1.29745340537246e-7,6.38595908814687e-8,3.11366791211496e-8,1.50438657136851e-8,7.20463139595471e-9,3.42096504735355e-9,1.61096089715013e-9,7.52543572340794e-10,3.48815510934873e-10,1.60465452033289e-10,7.32808935904165e-11,3.32295117925071e-11,1.49651694403587e-11],"fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fHistogram":{"_typename":"TH1F","fUniqueID":0,"fBits":50 ...
